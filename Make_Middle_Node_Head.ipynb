# %%
class Node():
    
    def __init__(self,data,next_node = None):
        
        self.data = data
        
        self.next_node = next_node
        
class Linked_List():
    
    def __init__(self,head = None):
        
        self.head = head
        
    def insertion(self,value):
        
        node = Node(value)
        
        if self.head is None:
            
            self.head = node
            
            return
        
        node.next_node= self.head
        
        self.head = node
        
    def insert_multiple(self,list):
        
        for values in list:
            
            self.insertion(values)
            
    def display_linked_list(self):
        
        if self.head is None:
            
            print("Linked_List is Empty")
            
            return
        
        current_node = self.head
        
        while current_node :
            
            print(current_node.data , end = " --> ")
            
            current_node = current_node.next_node
        
        print("Null")
        
    def make_mid_head(self):
        
        if self.head is None:
            
            print("Empty Linked_List")
            
            return
        
        prev_node = None
        
        slow = self.head
        
        fast = self.head
        
        while fast and fast.next_node:
            
            prev_node = slow
            
            slow = slow.next_node
            
            fast = fast.next_node.next_node
            
            
            
        
        
        prev_node.next_node = slow.next_node
        
        slow.next_node = self.head
        
        self.head = slow
        
        return
                                          # Time = O(n) ..... Space =O(1) 
        
        
            
            
ll = Linked_List()

ll.insert_multiple([5,4,3,2,1])

ll.display_linked_list()

ll.make_mid_head()

ll.display_linked_list()
# Out:
# 1 --> 2 --> 3 --> 4 --> 5 --> Null
# 3 --> 1 --> 2 --> 4 --> 5 --> Null
